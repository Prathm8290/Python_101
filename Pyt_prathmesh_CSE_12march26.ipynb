# %%
sales_data = ["1200", "1500", "1100", "1800", "1600", "1400", "1700"]


sales_num = []
for i in sales_data:
    if i not in sales_num:
        sales_num.append(int(i))
print(sales_data)
print(sales_num)
x="10"
print(x)
print(type(x))
y=int(x) 
print(y,type(y))
# Out:
# ['1200', '1500', '1100', '1800', '1600', '1400', '1700']
# [1200, 1500, 1100, 1800, 1600, 1400, 1700]
# 10
# <class 'str'>
# 10 <class 'int'>

# %%
#for i ,sales in enumerate(sale_numbers, starts=1):
# print (f ")

pairs = enumerate(sales_num, start=1)
print(dict(pairs))
# Out:
# {1: 1200, 2: 1500, 3: 1100, 4: 1800, 5: 1600, 6: 1400, 7: 1700}
